# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ## 2-1. 데이터 로드 및 연결

# %%
import numpy as np
import os

# GPU가 없는 시스템에서는 자동으로 CPU 모드로 실행됨.

# CUDA_VISIBLE_DEVICES 환경 변수를 설정하여 사용 가능한 GPU를 지정
# '1'번 GPU를 사용하도록 설정 (0번부터 시작하여 번호가 매겨짐)
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# TF_FORCE_GPU_ALLOW_GROWTH 환경 변수를 설정하여 TensorFlow가 GPU 메모리를 동적으로 사용할 수 있게 함
# 기본적으로 TensorFlow는 모든 GPU 메모리를 할당하지만, 이 설정을 통해 필요한 만큼만 할당하게 함
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
# 인식할 동작 목록 정의
actions = [
    'one',
    'two',
    'three',
    'four',
    'five',
    'good',
    'bad'
]

# 각 동작에 해당하는 데이터를 로드하여 하나의 배열로 연결
data = np.concatenate([
    np.load('dataset/seq_one_0_1718533020.npy'),
    np.load('dataset/seq_two_0_1718533020.npy'),
    np.load('dataset/seq_three_0_1718533020.npy'),
    np.load('dataset/seq_four_0_1718533020.npy'),
    np.load('dataset/seq_five_0_1718533020.npy'),
    np.load('dataset/seq_good_0_1718533020.npy'),
    np.load('dataset/seq_bad_0_1718533020.npy')
], axis=0) # 첫 번째 축(axis=0)을 따라 데이터를 연결

# 연결된 데이터의 형태 출력
data.shape # 예를 들어, (900, 30, 68)처럼 연결된 데이터의 차원 정보를 출력
# Out:
# (6079, 30, 100)

# %% [markdown]
# (6079, 30, 100)
#
# 전체 데이터 셋에 6079의 개별 시퀀스가 있음
#
# 각 시퀀스는 30개의 시간 단계(timesteps)로 구성되어 있음
#
# 각 시간 단계에는 100개의 피처(feature)가 있음
#
#
# 7가지 손동작을 합쳐서 총 6097번 촬영이 이루어졌다.
#
# 손동작마다 촬영된 횟수가 균등하지 않을 수 있다.

# %% [markdown]
# ## 2-2. 데이터 분리

# %% [markdown]
# ### 입력 데이터와 라벨 분리

# %%
# 데이터에서 입력 데이터(x_data)와 라벨(labels) 분리
# x_data는 마지막 축을 제외한 모든 데이터를 포함
# labels는 마지막 축의 첫 번째 값을 사용하여 각 시퀀스의 라벨로 설정
x_data = data[:, :, :-1]
labels = data[:, 0, -1]

# 분리된 데이터의 형태 출력
print(x_data.shape)   # 예를 들어, (900, 30, 67)
print(labels.shape)   # 예를 들어, (900,)
# Out:
# (6079, 30, 99)
# (6079,)

# %% [markdown]
# 입력 데이터 (x_data) : 모델에 입력으로 들어감, 여러 피처(특징)을 포함하고 있음. 모델이 학습을 통해 패턴을 인식하고 예측할 수 있도록 해줌. 마지막 축을 제외한 모든 데이터를 포함
#
#
# 라벨 (labels) : 각 입력 데이터에 대한 정답(타깃). 모델이 예측한 값과 비교하려 학습 성능을 평가하는 기준이 됨. 마지막 축의 첫 번째 값을 사용하여 각 시퀀스의 라벨로 설정

# %% [markdown]
# ### 라벨 원-핫 인코딩

# %%
# TensorFlow Keras의 to_categorical을 사용하여 라벨을 원-핫 인코딩
from tensorflow.keras.utils import to_categorical

# 원-핫 인코딩된 라벨 데이터 생성
y_data = to_categorical(labels, num_classes=len(actions))
y_data.shape  # 예를 들어, (900, 3)

#(6079, 7) 여기서 7은 클래스의 수
# Out:
# (6079, 7)

# %% [markdown]
# 원-핫 인코딩 : 각 라벨을 이진 벡터로 변환하는 과정. 모델이 각 클래스에 대한 확률을 출력할 수 있도록 함.
#
#     예를들어) 7개의 클래스가 있을 때, 라벨2는 [0, 0, 1, 0, 0, 0, 0]로 변환됨
#
#
# 타겟 데이터 (y_data) : 모델이 예측하려는 값. 예를들어 이미지에 해당하는 라벨 (one, two, three 등)

# %% [markdown]
# 위의 코드에서는 x_data와 labels 데이터로 나눈 후, labels 데이터를 원-핫 인코딩을 해서 y_data로 생성했음
#
# x_data : 독립변수 : 모델의 학습과 예측에 사용됨
#
# y_data : 종속변수 : 모델의 성능 평가와 학습 과정에서의 오류 계산에 사용됨

# %% [markdown]
# ## 2-3. 데이터셋 분할

# %%
# sklearn의 train_test_split을 사용하여 데이터셋을 학습 데이터와 검증 데이터로 분할
from sklearn.model_selection import train_test_split

# 데이터 타입을 float32로 변환
x_data = x_data.astype(np.float32)
y_data = y_data.astype(np.float32)

# 학습 데이터와 검증 데이터로 분할 (10%는 검증 데이터로 사용)
x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size=0.1, random_state=2021)

# train : 학습용
# val : 검증용

# 분할된 데이터셋의 형태 출력
print(x_train.shape, y_train.shape)  # 예를 들어, (810, 30, 67) (810, 3) #샘플수, 각 샘플의 시간단계 수, 각 시간 단계에서의 피처 수 / 샘플수, 출력 값 차원
print(x_val.shape, y_val.shape)      # 예를 들어, (90, 30, 67) (90, 3)
# Out:
# (5471, 30, 99) (5471, 7)
# (608, 30, 99) (608, 7)

# %% [markdown]
# 1. 데이터 타입 변환 :
#
# x_data와 y_data를 float32타입으로 변환 : float64 보다 더 적은 메모리를 사용. Tenserflow와 같은 딥러닝 프레임워크는 주로 float32 타입을 사용함. 이는 주로 메모리 사용을 최적화하고, 특정 딥러닝 프레임워크에서 요구하는 데이터 타입을 맞추기 위함임
#
#
# 2. 데이터셋 분할 :
#
# sklearn.model_selection 모듈의 train_test_split 함수를 사용하여 데이터를 학습 데이터와 검증 데이터로 분할함.
# 전체 데이터의 10%는 검증 데이터로 사용됨.

# %% [markdown]
# # 3. 모델 구축 및 컴파일

# %% [markdown]
# 텐서플로우 케라스를 사용하여 시계열 데이터를 처리하는 lstm 모델의 정의하고 학습시킴
#
# 케라스의 순차모델 (sequential) 을 사용하여 레이어를 순차적으로 쌓아올림.

# %% [markdown]
# 안녕하세요, 오늘 저는 TensorFlow와 Keras를 사용하여 LSTM 기반의 딥러닝 모델을 구축하고 학습시키는 방법에 대해 설명드리겠습니다. 이 코드의 각 부분을 차근차근 살펴보면서, 모델의 구축부터 학습까지의 전체 과정을 이해해보도록 하겠습니다.

# %% [markdown]
# # 1 모델 정의
#
# 먼저, Sequential 모델을 정의합니다. Sequential 모델은 레이어를 순차적으로 쌓아올리는 방식입니다.
#
# python

# %% [markdown]
# LSTM 레이어
#
#
# 첫 번째 레이어는 LSTM (Long Short-Term Memory) 레이어입니다. LSTM은 순환 신경망(RNN)의 일종으로, 시간에 따른 데이터의 패턴을 학습하는 데 유용합니다. 이 레이어는 64개의 유닛을 가지고 있으며, 활성화 함수로는 ReLU를 사용합니다. 입력 형태는 (시퀀스 길이, 피처 수)로 설정되어 있습니다.
#
#
# Dense 레이어
#
#
# 두 번째 레이어는 Dense 레이어로, 32개의 유닛과 ReLU 활성화 함수를 사용합니다.
# 마지막 레이어는 출력 레이어로, 인식할 동작의 수만큼의 유닛을 가지고 있으며, 소프트맥스 활성화 함수를 사용하여 다중 클래스 분류를 수행합니다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# 모델을 Sequential 형태로 정의
model = Sequential([
    # 첫 번째 LSTM 레이어
    # 유닛 수: 64, 활성화 함수: ReLU, 입력 형태: (시퀀스 길이, 피처 수)
    LSTM(64, activation='relu', input_shape=x_train.shape[1:3]),
    # 두 번째 Dense 레이어
    # 유닛 수: 32, 활성화 함수: ReLU
    Dense(32, activation='relu'),
    # 세 번째 Dense 레이어 (출력 레이어)
    # 유닛 수: 인식할 동작의 수, 활성화 함수: 소프트맥스
    Dense(len(actions), activation='softmax')
])
# Out:
# C:\Users\by130\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## 2 모델 컴파일 및 요약

# %% [markdown]
# 옵티마이저(Optimizer):
#
# 옵티마이저는 모델의 학습 과정을 조절하는 알고리즘입니다.
# Adam 옵티마이저는 경사 하강법을 기반으로 하는 알고리즘으로, 학습 속도를 조절하는 데 효과적입니다.
#
# 손실 함수 (Loss Function):
#
# 손실 함수는 모델의 예측값과 실제 값 간의 차이를 측정하는 함수입니다.
# 손실 함수로는 categorical_crossentropy를 사용합니다. 이는 다중 클래스 분류 문제에서 주로 사용되는 손실 함수입니다.
#
# 평가 메트릭(Metrics):
#
# 메트릭은 모델의 성능을 평가하기 위한 지표입니다.
# 평가 메트릭으로는 정확도(acc)를 사용합니다. 이는 모델의 성능을 평가하는 데 사용됩니다.

# %%
# 모델 컴파일
# 옵티마이저: Adam, 손실 함수: categorical_crossentropy, 메트릭: 정확도(acc)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

# 모델 요약 출력
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          41,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 7)                   │             231 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 44,295 (173.03 KB)
#  Trainable params: 44,295 (173.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 4 모델 학습

# %% [markdown]
# 이제 모델을 학습시킵니다. 학습 단계에서는 학습 데이터, 검증 데이터, 에포크 수, 그리고 콜백 함수들을 설정합니다.
#
#
# ModelCheckpoint 콜백
#
# ModelCheckpoint 콜백은 학습 과정 중 최상의 성능을 보이는 모델을 저장합니다. 여기서는 검증 정확도를 모니터링하고, 최상의 검증 정확도를 기록한 모델만 저장하도록 설정합니다.
#
# ReduceLROnPlateau 콜백
#
# ReduceLROnPlateau 콜백은 학습 속도를 동적으로 조정합니다. 검증 정확도가 50 에포크 동안 개선되지 않으면 학습 속도를 50%로 줄입니다. 이는 모델이 더 좋은 최적화 지점을 찾도록 도와줍니다.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# 모델 학습
history = model.fit(
    x_train,              # 학습 데이터
    y_train,              # 학습 라벨
    validation_data=(x_val, y_val),  # 검증 데이터 및 라벨
    epochs=200,           # 총 학습 에포크 수
    callbacks=[
        # ModelCheckpoint 콜백: 최적의 모델을 저장
        ModelCheckpoint(
            'models/model.keras',  # 모델 파일 저장 경로
            monitor='val_acc',         # 검증 정확도를 모니터링
            verbose=1,                 # 저장 시 메시지 출력
            save_best_only=True,       # 최상의 검증 정확도를 가진 모델만 저장
            mode='auto'                # 최적화 기준 모드 자동 설정
        ),
        # ReduceLROnPlateau 콜백: 학습 속도 조정
        ReduceLROnPlateau(
            monitor='val_acc',         # 검증 정확도를 모니터링
            factor=0.5,                # 학습 속도를 줄이는 비율
            patience=50,               # 50 에포크 동안 개선이 없으면 학습 속도를 줄임
            verbose=1,                 # 학습 속도 조정 시 메시지 출력
            mode='auto'                # 최적화 기준 모드 자동 설정
        )
    ]
)
# Out:
# Epoch 1/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1982 - loss: 204.3278
# Epoch 1: val_acc improved from -inf to 0.25658, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - acc: 0.1997 - loss: 203.3073 - val_acc: 0.2566 - val_loss: 121.3385 - learning_rate: 0.0010
# Epoch 2/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.2599 - loss: 134.1832
# Epoch 2: val_acc improved from 0.25658 to 0.35033, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.2595 - loss: 134.7659 - val_acc: 0.3503 - val_loss: 75.3148 - learning_rate: 0.0010
# Epoch 3/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.2308 - loss: 93.3362
# Epoch 3: val_acc improved from 0.35033 to 0.38487, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.2311 - loss: 92.9431 - val_acc: 0.3849 - val_loss: 18.7957 - learning_rate: 0.0010
# Epoch 4/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.3000 - loss: 161.0795
# Epoch 4: val_acc did not improve from 0.38487
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - acc: 0.2991 - loss: 162.1920 - val_acc: 0.2993 - val_loss: 153.4823 - learning_rate: 0.0010
# Epoch 5/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.3433 - loss: 127.4076
# Epoch 5: val_acc improved from 0.38487 to 0.45724, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.3443 - loss: 126.6115 - val_acc: 0.4572 - val_loss: 31.0003 - learning_rate: 0.0010
# Epoch 6/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.5148 - loss: 24.4538
# Epoch 6: val_acc improved from 0.45724 to 0.49671, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - acc: 0.5153 - loss: 24.3981 - val_acc: 0.4967 - val_loss: 20.4548 - learning_rate: 0.0010
# Epoch 7/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.5588 - loss: 15.4547
# Epoch 7: val_acc improved from 0.49671 to 0.58882, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.5592 - loss: 15.4259 - val_acc: 0.5888 - val_loss: 9.4128 - learning_rate: 0.0010
# Epoch 8/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.6220 - loss: 11.4158
# Epoch 8: val_acc improved from 0.58882 to 0.61513, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.6220 - loss: 11.4147 - val_acc: 0.6151 - val_loss: 12.8198 - learning_rate: 0.0010
# Epoch 9/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.6832 - loss: 7.2102
# Epoch 9: val_acc did not improve from 0.61513
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - acc: 0.6831 - loss: 7.2181 - val_acc: 0.5740 - val_loss: 13.5659 - learning_rate: 0.0010
# Epoch 10/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.6535 - loss: 9.7585
# Epoch 10: val_acc improved from 0.61513 to 0.68092, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.6534 - loss: 9.7508 - val_acc: 0.6809 - val_loss: 5.6813 - learning_rate: 0.0010
# Epoch 11/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.6754 - loss: 7.3865
# Epoch 11: val_acc did not improve from 0.68092
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.6754 - loss: 7.3872 - val_acc: 0.5559 - val_loss: 22.4739 - learning_rate: 0.0010
# Epoch 12/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0
200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.6991 - loss: 4.2584
# Epoch 63: val_acc did not improve from 0.83553
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - acc: 0.6998 - loss: 4.2300 - val_acc: 0.7253 - val_loss: 2.4100 - learning_rate: 0.0010
# Epoch 64/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.7413 - loss: 2.6653
# Epoch 64: val_acc improved from 0.83553 to 0.86349, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.7414 - loss: 2.6629 - val_acc: 0.8635 - val_loss: 0.6527 - learning_rate: 0.0010
# Epoch 65/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.7748 - loss: 2.0501
# Epoch 65: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.7747 - loss: 2.0506 - val_acc: 0.8010 - val_loss: 0.9824 - learning_rate: 0.0010
# Epoch 66/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.7542 - loss: 2.3397
# Epoch 66: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.7542 - loss: 2.3396 - val_acc: 0.7155 - val_loss: 1.5869 - learning_rate: 0.0010
# Epoch 67/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.7233 - loss: 3.0000
# Epoch 67: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.7240 - loss: 2.9872 - val_acc: 0.7434 - val_loss: 1.6714 - learning_rate: 0.0010
# Epoch 68/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.7446 - loss: 2.1905
# Epoch 68: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.7444 - loss: 2.2082 - val_acc: 0.6266 - val_loss: 3.9342 - learning_rate: 0.0010
# Epoch 69/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.7106 - loss: 3.5254
# Epoch 69: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.7112 - loss: 3.5125 - val_acc: 0.7138 - val_loss: 1.9863 - learning_rate: 0.0010
# Epoch 70/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.7928 - loss: 1.6358
# Epoch 70: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - acc: 0.7927 - loss: 1.6380 - val_acc: 0.7796 - val_loss: 1.2965 - learning_rate: 0.0010
# Epoch 71/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.7825 - loss: 2.8951
# Epoch 71: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.7818 - loss: 2.9107 - val_acc: 0.7582 - val_loss: 2.2886 - learning_rate: 0.0010
# Epoch 72/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.7861 - loss: 1.7790
# Epoch 72: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.7859 - loss: 1.7853 - val_acc: 0.7336 - val_loss: 2.8977 - learning_rate: 0.0010
# Epoch 73/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.7746 - loss: 2.0614
# Epoch 73: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.7750 - loss: 2.0590 - val_acc: 0.7845 - val_loss: 1.5680 - learning_rate: 0.0010
# Epoch 74/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.7948 - loss: 1.6728
# Epoch 74: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.7948 - loss: 1.6729 - val_acc: 0.7188 - val_loss: 2.4687 - learning_rate: 0.0010
# Epoch 75/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.7716 - loss: 2.7898
# Epoch 75: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.7720 - loss: 2.7815 - val_acc: 0.7122 - val_loss: 4.4332 - learning_rate: 0.0010
# Epoch 76/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.8032 - loss: 1.8250
# Epoch 76: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.8031 - loss: 1.8263 - val_acc: 0.7796 - val_loss: 1.2054 - learning_rate: 0.0010
# Epoch 77/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.8052 - loss: 1.4439
# Epoch 77: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.8051 - loss: 1.4456 - val_acc: 0.6464 - val_loss: 3.2088 - learning_rate: 0.0010
# Epoch 78/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.7304 - loss: 3.3736
# Epoch 78: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.7314 - loss: 3.3503 - val_acc: 0.7352 - val_loss: 3.2152 - learning_rate: 0.0010
# Epoch 79/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.7991 - loss: 2.0290
# Epoch 79: val_acc did not improve from 0.86349
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.7992 - loss: 2.0341 - val_acc: 0.7895 - val_loss: 1.3646 - learning_rate: 0.0010
# Epoch 80/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.7936 - loss: 1.9150
# Epoch 80: val_acc improved from 0.86349 to 0.88322, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.7935 - loss: 1.9203 - val_acc: 0.8832 - val_loss: 0.4214 - learning_rate: 0.0010
# Epoch 81/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.8290 - loss: 1.3955
# Epoch 81: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.8289 - loss: 1.3939 - val_acc: 0.8503 - val_loss: 0.9803 - learning_rate: 0.0010
# Epoch 82/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.8278 - loss: 1.4066
# Epoch 82: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.8279 - loss: 1.4034 - val_acc: 0.7993 - val_loss: 1.3314 - learning_rate: 0.0010
# Epoch 83/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.7999 - loss: 1.9571
# Epoch 83: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.7999 - loss: 1.9589 - val_acc: 0.7697 - val_loss: 2.7992 - learning_rate: 0.0010
# Epoch 84/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.8381 - loss: 1.2224
# Epoch 84: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.8379 - loss: 1.2223 - val_acc: 0.8536 - val_loss: 0.7980 - learning_rate: 0.0010
# Epoch 85/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.8303 - loss: 1.1587
# Epoch 85: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.8301 - loss: 1.1631 - val_acc: 0.8092 - val_loss: 1.7193 - learning_rate: 0.0010
# Epoch 86/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.8016 - loss: 1.5213
# Epoch 86: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.8018 - loss: 1.5207 - val_acc: 0.8306 - val_loss: 0.9710 - learning_rate: 0.0010
# Epoch 87/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.8220 - loss: 1.7317
# Epoch 87: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.8220 - loss: 1.7292 - val_acc: 0.8026 - val_loss: 2.0932 - learning_rate: 0.0010
# Epoch 88/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.8349 - loss: 1.6719
# Epoch 88: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.8349 - loss: 1.6712 - val_acc: 0.8158 - val_loss: 1.3023 - learning_rate: 0.0010
# Epoch 89/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.8244 - loss: 1.4535
# Epoch 89: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.8248 - loss: 1.4469 - val_acc: 0.8388 - val_loss: 0.6675 - learning_rate: 0.0010
# Epoch 90/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.8433 - loss: 1.3269
# Epoch 90: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.8431 - loss: 1.3320 - val_acc: 0.8750 - val_loss: 0.5846 - learning_rate: 0.0010
# Epoch 91/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.8596 - loss: 1.1119
# Epoch 91: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.8596 - loss: 1.1140 - val_acc: 0.8438 - val_loss: 1.4856 - learning_rate: 0.0010
# Epoch 92/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.8624 - loss: 0.8387
# Epoch 92: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.8625 - loss: 0.8385 - val_acc: 0.8059 - val_loss: 1.5902 - learning_rate: 0.0010
# Epoch 93/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.8468 - loss: 1.0671
# Epoch 93: val_acc did not improve from 0.88322
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.8468 - loss: 1.0668 - val_acc: 0.8832 - val_loss: 0.4703 - learning_rate: 0.0010
# Epoch 94/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.8650 - loss: 0.7719
# Epoch 94: val_acc improved from 0.88322 to 0.90132, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0
200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.9618 - loss: 0.0987
# Epoch 161: val_acc improved from 0.98191 to 0.98355, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.9618 - loss: 0.0985 - val_acc: 0.9836 - val_loss: 0.0486 - learning_rate: 0.0010
# Epoch 162/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.9789 - loss: 0.0497
# Epoch 162: val_acc improved from 0.98355 to 0.98684, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - acc: 0.9789 - loss: 0.0496 - val_acc: 0.9868 - val_loss: 0.0362 - learning_rate: 0.0010
# Epoch 163/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9680 - loss: 0.2149
# Epoch 163: val_acc did not improve from 0.98684
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.9669 - loss: 0.2227 - val_acc: 0.8553 - val_loss: 0.4396 - learning_rate: 0.0010
# Epoch 164/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.8624 - loss: 0.6293
# Epoch 164: val_acc did not improve from 0.98684
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.8625 - loss: 0.6274 - val_acc: 0.9145 - val_loss: 0.1761 - learning_rate: 0.0010
# Epoch 165/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.9226 - loss: 0.2002
# Epoch 165: val_acc did not improve from 0.98684
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.9228 - loss: 0.1995 - val_acc: 0.9375 - val_loss: 0.1421 - learning_rate: 0.0010
# Epoch 166/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.9355 - loss: 0.1598
# Epoch 166: val_acc did not improve from 0.98684
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.9353 - loss: 0.1602 - val_acc: 0.9457 - val_loss: 0.1401 - learning_rate: 0.0010
# Epoch 167/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.9484 - loss: 0.1180
# Epoch 167: val_acc did not improve from 0.98684
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.9483 - loss: 0.1180 - val_acc: 0.9572 - val_loss: 0.0977 - learning_rate: 0.0010
# Epoch 168/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - acc: 0.9658 - loss: 0.0903
# Epoch 168: val_acc did not improve from 0.98684
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.9658 - loss: 0.0902 - val_acc: 0.9671 - val_loss: 0.0748 - learning_rate: 0.0010
# Epoch 169/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.9801 - loss: 0.0576
# Epoch 169: val_acc did not improve from 0.98684
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - acc: 0.9801 - loss: 0.0575 - val_acc: 0.9819 - val_loss: 0.0593 - learning_rate: 0.0010
# Epoch 170/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - acc: 0.9815 - loss: 0.0460
# Epoch 170: val_acc did not improve from 0.98684
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - acc: 0.9815 - loss: 0.0460 - val_acc: 0.9753 - val_loss: 0.0686 - learning_rate: 0.0010
# Epoch 171/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.9778 - loss: 0.0485
# Epoch 171: val_acc improved from 0.98684 to 0.99178, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.9778 - loss: 0.0485 - val_acc: 0.9918 - val_loss: 0.0354 - learning_rate: 0.0010
# Epoch 172/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9856 - loss: 0.0386
# Epoch 172: val_acc did not improve from 0.99178
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.9856 - loss: 0.0386 - val_acc: 0.9868 - val_loss: 0.0425 - learning_rate: 0.0010
# Epoch 173/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9712 - loss: 0.0681
# Epoch 173: val_acc did not improve from 0.99178
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.9713 - loss: 0.0679 - val_acc: 0.9852 - val_loss: 0.0356 - learning_rate: 0.0010
# Epoch 174/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9821 - loss: 0.0536
# Epoch 174: val_acc did not improve from 0.99178
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.9820 - loss: 0.0537 - val_acc: 0.9868 - val_loss: 0.0438 - learning_rate: 0.0010
# Epoch 175/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9841 - loss: 0.0410
# Epoch 175: val_acc did not improve from 0.99178
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.9841 - loss: 0.0410 - val_acc: 0.9868 - val_loss: 0.0322 - learning_rate: 0.0010
# Epoch 176/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9875 - loss: 0.0322
# Epoch 176: val_acc did not improve from 0.99178
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0
200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9947 - loss: 0.0140
# Epoch 192: val_acc improved from 0.99507 to 0.99836, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.9947 - loss: 0.0140 - val_acc: 0.9984 - val_loss: 0.0086 - learning_rate: 0.0010
# Epoch 193/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9933 - loss: 0.0144
# Epoch 193: val_acc did not improve from 0.99836
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.9932 - loss: 0.0145 - val_acc: 0.9967 - val_loss: 0.0057 - learning_rate: 0.0010
# Epoch 194/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.9904 - loss: 0.0238
# Epoch 194: val_acc did not improve from 0.99836
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.9905 - loss: 0.0238 - val_acc: 0.9984 - val_loss: 0.0083 - learning_rate: 0.0010
# Epoch 195/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9953 - loss: 0.0122
# Epoch 195: val_acc did not improve from 0.99836
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.9953 - loss: 0.0122 - val_acc: 0.9901 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 196/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9959 - loss: 0.0121
# Epoch 196: val_acc did not improve from 0.99836
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.9957 - loss: 0.0125 - val_acc: 0.9934 - val_loss: 0.0169 - learning_rate: 0.0010
# Epoch 197/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.9926 - loss: 0.0189
# Epoch 197: val_acc did not improve from 0.99836
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.9927 - loss: 0.0188 - val_acc: 0.9967 - val_loss: 0.0101 - learning_rate: 0.0010
# Epoch 198/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9944 - loss: 0.0182
# Epoch 198: val_acc did not improve from 0.99836
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.9944 - loss: 0.0185 - val_acc: 0.9753 - val_loss: 0.0697 - learning_rate: 0.0010
# Epoch 199/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9824 - loss: 0.0507
# Epoch 199: val_acc did not improve from 0.99836
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.9823 - loss: 0.0508 - val_acc: 0.9934 - val_loss: 0.0314 - learning_rate: 0.0010
# Epoch 200/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.9882 - loss: 0.0390
# Epoch 200: val_acc did not improve from 0.99836
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.9882 - loss: 0.0391 - val_acc: 0.9934 - val_loss: 0.0166 - learning_rate: 0.0010

# %% [markdown]
# 결론
# 이렇게 해서 우리는 LSTM 기반의 딥러닝 모델을 정의하고, 이를 컴파일하고, 학습시키는 전체 과정을 살펴보았습니다. 각 단계마다 중요한 설정들이 있으며, 이러한 설정들이 모델의 성능에 큰 영향을 미칩니다. 오늘 설명드린 내용이 여러분의 딥러닝 모델 구축에 도움이 되길 바랍니다. 감사합니다.

# %% [markdown]
# # 모델 성능 평가

# %% [markdown]
# ## 손실/정확도 시각화
#
#
# 그래프 생성: matplotlib 라이브러리를 사용하여 손실과 정확도를 시각화합니다.
#
# 손실 그래프 설정: 학습 손실과 검증 손실을 각각 노란색과 빨간색으로 표시합니다.
#
# 정확도 그래프 설정: 학습 정확도와 검증 정확도를 각각 파란색과 녹색으로 표시합니다.
#
# 결과 시각화: 에포크(epoch)별로 모델의 성능 변화를 쉽게 파악할 수 있습니다.

# %%
import matplotlib.pyplot as plt

# 그래프 생성
fig, loss_ax = plt.subplots(figsize=(16, 10))
acc_ax = loss_ax.twinx()

# 손실 그래프 설정
loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

# 정확도 그래프 설정
acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

# 그래프 출력
plt.show()

# %% [markdown]
# ## 모델 로드 및 검증 데이터 예측
#
# 모델 로드: tensorflow.keras.models의 load_model 함수를 사용하여 저장된 모델을 불러옵니다.
#
# 모델 예측: 로드된 모델을 사용하여 검증 데이터에 대한 예측을 수행합니다.
#
# 검증 데이터: 사전에 분리된 데이터를 사용하여 모델의 일반화 성능을 평가합니다.
#
# ## 다중 라벨 혼동 행렬 계산
#
# 혼동 행렬: sklearn.metrics의 multilabel_confusion_matrix를 사용하여 다중 라벨 분류 문제의 성능을 평가합니다.
#
# 혼동 행렬 계산: 실제 라벨과 예측 라벨을 비교하여 각 클래스에 대한 혼동 행렬을 생성합니다.
#
# 결과 해석: 혼동 행렬을 통해 모델이 어떤 클래스에서 잘못된 예측을 했는지 구체적으로 파악할 수 있습니다.

# %%
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.models import load_model

# 저장된 모델 로드
model = load_model('models/model.keras')

# 검증 데이터를 사용하여 모델의 예측 수행
y_pred = model.predict(x_val)

# 다중 라벨 혼동 행렬 계산
confusion_matrices = multilabel_confusion_matrix(np.argmax(y_val, axis=1), np.argmax(y_pred, axis=1))

# 다중 라벨 혼동 행렬 출력
confusion_matrices
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# array([[[518,   0],
#         [  0,  90]],
#
#        [[531,   0],
#         [  0,  77]],
#
#        [[526,   0],
#         [  0,  82]],
#
#        [[531,   0],
#         [  0,  77]],
#
#        [[517,   0],
#         [  0,  91]],
#
#        [[513,   1],
#         [  0,  94]],
#
#        [[511,   0],
#         [  1,  96]]], dtype=int64)

# %% [markdown]
# ## 예외 처리 및 파일 존재 여부 확인   : ppt(X)
#
# 예외 처리: 모델 파일이 존재하지 않을 경우를 대비하여 예외 처리를 수행합니다.
#
# 파일 확인: os.path.exists를 사용하여 모델 파일의 존재 여부를 확인합니다.
#
# 오류 처리: 파일이 존재하지 않을 경우 FileNotFoundError를 발생시켜 사용자에게 알립니다.
#
# 전체 흐름: 모델 로드, 예측, 혼동 행렬 계산, 및 예외 처리를 포함한 전체 흐름을 관리합니다.

# %%
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.models import load_model
import os

# 모델 파일 경로 정의
model_file = 'models/model.keras'

try:
    # 파일 존재 여부 확인
    if os.path.exists(model_file):
        # 모델 로드
        model = load_model(model_file)

        # 검증 데이터에 대한 예측 수행
        y_pred = model.predict(x_val)

        # 다중 라벨 혼동 행렬 계산
        confusion_matrices = multilabel_confusion_matrix(np.argmax(y_val, axis=1), np.argmax(y_pred, axis=1))

        # 혼동 행렬 출력
        print(confusion_matrices)
    else:
        raise FileNotFoundError(f"모델 파일 '{model_file}'을 찾을 수 없습니다.")
except Exception as e:
    print("오류가 발생했습니다:", e)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [[[518   0]
#   [  0  90]]
#
#  [[531   0]
#   [  0  77]]
#
#  [[526   0]
#   [  0  82]]
#
#  [[531   0]
#   [  0  77]]
#
#  [[517   0]
#   [  0  91]]
#
#  [[513   1]
#   [  0  94]]
#
#  [[511   0]
#   [  1  96]]]
