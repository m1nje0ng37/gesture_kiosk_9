# %% [markdown]
# # 2. 데이터 전처리

# %% [markdown]
# ## 2-1. 데이터 로드 및 연결

# %%
import numpy as np
import os

# GPU가 없는 시스템에서는 자동으로 CPU 모드로 실행됨.

# CUDA_VISIBLE_DEVICES 환경 변수를 설정하여 사용 가능한 GPU를 지정
# '1'번 GPU를 사용하도록 설정 (0번부터 시작하여 번호가 매겨짐)
os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# TF_FORCE_GPU_ALLOW_GROWTH 환경 변수를 설정하여 TensorFlow가 GPU 메모리를 동적으로 사용할 수 있게 함
# 기본적으로 TensorFlow는 모든 GPU 메모리를 할당하지만, 이 설정을 통해 필요한 만큼만 할당하게 함
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
# 인식할 동작 목록 정의
actions = [
    'one',
    'two',
    'three',
    'four',
    'five',
    'good',
    'bad'
]

# 각 동작에 해당하는 데이터를 로드하여 하나의 배열로 연결
data = np.concatenate([
    np.load('dataset/seq_one_1718555953.npy'),
    np.load('dataset/seq_two_1718555953.npy'),
    np.load('dataset/seq_three_1718555953.npy'),
    np.load('dataset/seq_four_1718555953.npy'),
    np.load('dataset/seq_five_1718555953.npy'),
    np.load('dataset/seq_good_1718555953.npy'),
    np.load('dataset/seq_bad_1718555953.npy')
], axis=0) # 첫 번째 축(axis=0)을 따라 데이터를 연결

# 연결된 데이터의 형태 출력
data.shape # 예를 들어, (900, 30, 68)처럼 연결된 데이터의 차원 정보를 출력
# Out:
# (6079, 30, 100)

# %% [markdown]
# (6079, 30, 100)
#
# 전체 데이터 셋에 6079의 개별 시퀀스가 있음
#
# 각 시퀀스는 30개의 시간 단계(timesteps)로 구성되어 있음
#
# 각 시간 단계에는 100개의 피처(feature)가 있음
#
#
# 7가지 손동작을 합쳐서 총 6097번 촬영이 이루어졌다.
#
# 손동작마다 촬영된 횟수가 균등하지 않을 수 있다.

# %% [markdown]
# ## 2-2. 데이터 분리

# %% [markdown]
# ### 입력 데이터와 라벨 분리

# %%
# 데이터에서 입력 데이터(x_data)와 라벨(labels) 분리
# x_data는 마지막 축을 제외한 모든 데이터를 포함
# labels는 마지막 축의 첫 번째 값을 사용하여 각 시퀀스의 라벨로 설정
x_data = data[:, :, :-1]
labels = data[:, 0, -1]

# 분리된 데이터의 형태 출력
print(x_data.shape)   # 예를 들어, (900, 30, 67)
print(labels.shape)   # 예를 들어, (900,)
# Out:
# (6079, 30, 99)
# (6079,)

# %% [markdown]
# 입력 데이터 (x_data) : 모델에 입력으로 들어감, 여러 피처(특징)을 포함하고 있음. 모델이 학습을 통해 패턴을 인식하고 예측할 수 있도록 해줌. 마지막 축을 제외한 모든 데이터를 포함
#
#
# 라벨 (labels) : 각 입력 데이터에 대한 정답(타깃). 모델이 예측한 값과 비교하려 학습 성능을 평가하는 기준이 됨. 마지막 축의 첫 번째 값을 사용하여 각 시퀀스의 라벨로 설정

# %% [markdown]
# ### 라벨 원-핫 인코딩

# %%
# TensorFlow Keras의 to_categorical을 사용하여 라벨을 원-핫 인코딩
from tensorflow.keras.utils import to_categorical

# 원-핫 인코딩된 라벨 데이터 생성
y_data = to_categorical(labels, num_classes=len(actions))
y_data.shape  # 예를 들어, (900, 3)

#(6079, 7) 여기서 7은 클래스의 수
# Out:
# (6079, 7)

# %% [markdown]
# 원-핫 인코딩 : 각 라벨을 이진 벡터로 변환하는 과정. 모델이 각 클래스에 대한 확률을 출력할 수 있도록 함.
#
#     예를들어) 7개의 클래스가 있을 때, 라벨2는 [0, 0, 1, 0, 0, 0, 0]로 변환됨
#
#
# 타겟 데이터 (y_data) : 모델이 예측하려는 값. 예를들어 이미지에 해당하는 라벨 (one, two, three 등)

# %% [markdown]
# 위의 코드에서는 x_data와 labels 데이터로 나눈 후, labels 데이터를 원-핫 인코딩을 해서 y_data로 생성했음
#
# x_data : 독립변수 : 모델의 학습과 예측에 사용됨
#
# y_data : 종속변수 : 모델의 성능 평가와 학습 과정에서의 오류 계산에 사용됨

# %% [markdown]
# ## 2-3. 데이터셋 분할

# %%
# sklearn의 train_test_split을 사용하여 데이터셋을 학습 데이터와 검증 데이터로 분할
from sklearn.model_selection import train_test_split

# 데이터 타입을 float32로 변환
x_data = x_data.astype(np.float32)
y_data = y_data.astype(np.float32)

# 학습 데이터와 검증 데이터로 분할 (10%는 검증 데이터로 사용)
x_train, x_val, y_train, y_val = train_test_split(x_data, y_data, test_size=0.1, random_state=2021)

# train : 학습용
# val : 검증용

# 분할된 데이터셋의 형태 출력
print(x_train.shape, y_train.shape)  # 예를 들어, (810, 30, 67) (810, 3) #샘플수, 각 샘플의 시간단계 수, 각 시간 단계에서의 피처 수 / 샘플수, 출력 값 차원
print(x_val.shape, y_val.shape)      # 예를 들어, (90, 30, 67) (90, 3)
# Out:
# (5471, 30, 99) (5471, 7)
# (608, 30, 99) (608, 7)

# %% [markdown]
# 1. 데이터 타입 변환 :
#
# x_data와 y_data를 float32타입으로 변환 : float64 보다 더 적은 메모리를 사용. Tenserflow와 같은 딥러닝 프레임워크는 주로 float32 타입을 사용함. 이는 주로 메모리 사용을 최적화하고, 특정 딥러닝 프레임워크에서 요구하는 데이터 타입을 맞추기 위함임
#
#
# 2. 데이터셋 분할 :
#
# sklearn.model_selection 모듈의 train_test_split 함수를 사용하여 데이터를 학습 데이터와 검증 데이터로 분할함.
# 전체 데이터의 10%는 검증 데이터로 사용됨.

# %% [markdown]
# # 3. 모델 구축 및 컴파일

# %% [markdown]
# 텐서플로우 케라스를 사용하여 시계열 데이터를 처리하는 lstm 모델의 정의하고 학습시킴
#
# 케라스의 순차모델 (sequential) 을 사용하여 레이어를 순차적으로 쌓아올림.

# %% [markdown]
# 안녕하세요, 오늘 저는 TensorFlow와 Keras를 사용하여 LSTM 기반의 딥러닝 모델을 구축하고 학습시키는 방법에 대해 설명드리겠습니다. 이 코드의 각 부분을 차근차근 살펴보면서, 모델의 구축부터 학습까지의 전체 과정을 이해해보도록 하겠습니다.

# %% [markdown]
# # 1 모델 정의
#
# 먼저, Sequential 모델을 정의합니다. Sequential 모델은 레이어를 순차적으로 쌓아올리는 방식입니다.
#
# python

# %% [markdown]
# LSTM 레이어
#
#
# 첫 번째 레이어는 LSTM (Long Short-Term Memory) 레이어입니다. LSTM은 순환 신경망(RNN)의 일종으로, 시간에 따른 데이터의 패턴을 학습하는 데 유용합니다. 이 레이어는 64개의 유닛을 가지고 있으며, 활성화 함수로는 ReLU를 사용합니다. 입력 형태는 (시퀀스 길이, 피처 수)로 설정되어 있습니다.
#
#
# Dense 레이어
#
#
# 두 번째 레이어는 Dense 레이어로, 32개의 유닛과 ReLU 활성화 함수를 사용합니다.
# 마지막 레이어는 출력 레이어로, 인식할 동작의 수만큼의 유닛을 가지고 있으며, 소프트맥스 활성화 함수를 사용하여 다중 클래스 분류를 수행합니다.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# 모델을 Sequential 형태로 정의
model = Sequential([
    # 첫 번째 LSTM 레이어
    # 유닛 수: 64, 활성화 함수: ReLU, 입력 형태: (시퀀스 길이, 피처 수)
    LSTM(64, activation='relu', input_shape=x_train.shape[1:3]),
    # 두 번째 Dense 레이어
    # 유닛 수: 32, 활성화 함수: ReLU
    Dense(32, activation='relu'),
    # 세 번째 Dense 레이어 (출력 레이어)
    # 유닛 수: 인식할 동작의 수, 활성화 함수: 소프트맥스
    Dense(len(actions), activation='softmax')
])
# Out:
# C:\Users\by130\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## 2 모델 컴파일 및 요약

# %% [markdown]
# 옵티마이저(Optimizer):
#
# 옵티마이저는 모델의 학습 과정을 조절하는 알고리즘입니다.
# Adam 옵티마이저는 경사 하강법을 기반으로 하는 알고리즘으로, 학습 속도를 조절하는 데 효과적입니다.
#
# 손실 함수 (Loss Function):
#
# 손실 함수는 모델의 예측값과 실제 값 간의 차이를 측정하는 함수입니다.
# 손실 함수로는 categorical_crossentropy를 사용합니다. 이는 다중 클래스 분류 문제에서 주로 사용되는 손실 함수입니다.
#
# 평가 메트릭(Metrics):
#
# 메트릭은 모델의 성능을 평가하기 위한 지표입니다.
# 평가 메트릭으로는 정확도(acc)를 사용합니다. 이는 모델의 성능을 평가하는 데 사용됩니다.

# %%
# 모델 컴파일
# 옵티마이저: Adam, 손실 함수: categorical_crossentropy, 메트릭: 정확도(acc)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['acc'])

# 모델 요약 출력
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          41,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │             231 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 44,295 (173.03 KB)
#  Trainable params: 44,295 (173.03 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 4 모델 학습

# %% [markdown]
# 이제 모델을 학습시킵니다. 학습 단계에서는 학습 데이터, 검증 데이터, 에포크 수, 그리고 콜백 함수들을 설정합니다.
#
#
# ModelCheckpoint 콜백
#
# ModelCheckpoint 콜백은 학습 과정 중 최상의 성능을 보이는 모델을 저장합니다. 여기서는 검증 정확도를 모니터링하고, 최상의 검증 정확도를 기록한 모델만 저장하도록 설정합니다.
#
# ReduceLROnPlateau 콜백
#
# ReduceLROnPlateau 콜백은 학습 속도를 동적으로 조정합니다. 검증 정확도가 50 에포크 동안 개선되지 않으면 학습 속도를 50%로 줄입니다. 이는 모델이 더 좋은 최적화 지점을 찾도록 도와줍니다.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

# 모델 학습
history = model.fit(
    x_train,              # 학습 데이터
    y_train,              # 학습 라벨
    validation_data=(x_val, y_val),  # 검증 데이터 및 라벨
    epochs=200,           # 총 학습 에포크 수
    callbacks=[
        # ModelCheckpoint 콜백: 최적의 모델을 저장
        ModelCheckpoint(
            'models/model.keras',  # 모델 파일 저장 경로
            monitor='val_acc',         # 검증 정확도를 모니터링
            verbose=1,                 # 저장 시 메시지 출력
            save_best_only=True,       # 최상의 검증 정확도를 가진 모델만 저장
            mode='auto'                # 최적화 기준 모드 자동 설정
        ),
        # ReduceLROnPlateau 콜백: 학습 속도 조정
        ReduceLROnPlateau(
            monitor='val_acc',         # 검증 정확도를 모니터링
            factor=0.5,                # 학습 속도를 줄이는 비율
            patience=50,               # 50 에포크 동안 개선이 없으면 학습 속도를 줄임
            verbose=1,                 # 학습 속도 조정 시 메시지 출력
            mode='auto'                # 최적화 기준 모드 자동 설정
        )
    ]
)
# Out:
# Epoch 1/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1588 - loss: 663.1050
# Epoch 1: val_acc improved from -inf to 0.18421, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - acc: 0.1592 - loss: 658.5956 - val_acc: 0.1842 - val_loss: 275.0246 - learning_rate: 0.0010
# Epoch 2/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.2030 - loss: 229.0907
# Epoch 2: val_acc improved from 0.18421 to 0.36184, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.2035 - loss: 227.2227 - val_acc: 0.3618 - val_loss: 57.2098 - learning_rate: 0.0010
# Epoch 3/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.2608 - loss: 87.1829
# Epoch 3: val_acc did not improve from 0.36184
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - acc: 0.2606 - loss: 87.1906 - val_acc: 0.2516 - val_loss: 48.8584 - learning_rate: 0.0010
# Epoch 4/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.2241 - loss: 67.7188
# Epoch 4: val_acc did not improve from 0.36184
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.2239 - loss: 67.8007 - val_acc: 0.3141 - val_loss: 52.6154 - learning_rate: 0.0010
# Epoch 5/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.2503 - loss: 59.1188
# Epoch 5: val_acc did not improve from 0.36184
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.2503 - loss: 59.0192 - val_acc: 0.3191 - val_loss: 40.0519 - learning_rate: 0.0010
# Epoch 6/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.3769 - loss: 26.9817
# Epoch 6: val_acc improved from 0.36184 to 0.51645, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.3776 - loss: 26.9196 - val_acc: 0.5164 - val_loss: 22.4416 - learning_rate: 0.0010
# Epoch 7/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.4934 - loss: 23.6797
# Epoch 7: val_acc did not improve from 0.51645
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.4903 - loss: 23.7241 - val_acc: 0.2961 - val_loss: 10.0571 - learning_rate: 0.0010
# Epoch 8/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.3366 - loss: 11.0364
# Epoch 8: val_acc did not improve from 0.51645
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.3358 - loss: 11.3421 - val_acc: 0.1645 - val_loss: 316.9832 - learning_rate: 0.0010
# Epoch 9/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.3029 - loss: 63.1502
# Epoch 9: val_acc improved from 0.51645 to 0.52796, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.3033 - loss: 62.8975 - val_acc: 0.5280 - val_loss: 1.9571 - learning_rate: 0.0010
# Epoch 10/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.5284 - loss: 2.0339
# Epoch 10: val_acc improved from 0.52796 to 0.53947, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.5288 - loss: 2.0281 - val_acc: 0.5395 - val_loss: 1.5526 - learning_rate: 0.0010
# Epoch 11/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.5943 - loss: 1.3513
# Epoch 11: val_acc improved from 0.53947 to 0.64309, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.5947 - loss: 1.3495 - val_acc: 0.6431 - val_loss: 1.3535 - learning_rate: 0.0010
# Epoch 12/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.6367 - loss: 1.1635
# Epoch 12: val_acc improved from 0.64309 to 0.65954, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.6371 - loss: 1.1627 - val_acc: 0.6595 - val_loss: 1.0293 - learning_rate: 0.0010
# Epoch 13/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.6831 - loss: 1.0253
# Epoch 13: val_acc did not improve from 0.65954
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.6831 - loss: 1.0257 - val_acc: 0.6020 - val_loss: 1.0101 - learning_rate: 0.0010
# Epoch 14/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.6862 - loss: 0.9759
# Epoch 14: val_acc improved from 0.65954 to 0.69408, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.6862 - loss: 0.9760 - val_acc: 0.6941 - val_loss: 1.2827 - learning_rate: 0.0010
# Epoch 15/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.7034 - loss: 0.9364
# Epoch 15: val_acc did not improve from 0.69408
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.7035 - loss: 0.9367 - val_acc: 0.5707 - val_loss: 1.1690 - learning_rate: 0.0010
# Epoch 16/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.7045 - loss: 0.8789
# Epoch 16: val_acc did not improve from 0.69408
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.7047 - loss: 0.8785 - val_acc: 0.6711 - val_loss: 1.3282 - learning_rate: 0.0010
# Epoch 17/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.7119 - loss: 0.9159
# Epoch 17: val_acc improved from 0.69408 to 0.72368, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.7119 - loss: 0.9155 - val_acc: 0.7237 - val_loss: 0.7585 - learning_rate: 0.0010
# Epoch 18/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.7364 - loss: 0.8029
# Epoch 18: val_acc did not improve from 0.72368
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.7365 - loss: 0.8027 - val_acc: 0.6974 - val_loss: 0.7094 - learning_rate: 0.0010
# Epoch 19/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.7464 - loss: 0.7585
# Epoch 19: val_acc improved from 0.72368 to 0.73684, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.7462 - loss: 0.7601 - val_acc: 0.7368 - val_loss: 0.7189 - learning_rate: 0.0010
# Epoch 20/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.7626 - loss: 0.6929
# Epoch 20: val_acc improved from 0.73684 to 0.74013, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.7628 - loss: 0.6924 - val_acc: 0.7401 - val_loss: 0.7283 - learning_rate: 0.0010
# Epoch 21/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.7695 - loss: 0.6647
# Epoch 21: val_acc did not improve from 0.74013
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.7694 - loss: 0.6648 - val_acc: 0.6760 - val_loss: 0.7675 - learning_rate: 0.0010
# Epoch 22/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.7717 - loss: 0.7004
# Epoch 22: val_acc did not improve from 0.74013
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.7718 - loss: 0.6996 - val_acc: 0.7352 - val_loss: 0.8021 - learning_rate: 0.0010
# Epoch 23/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.7836 - loss: 0.6493
# Epoch 23: val_acc improved from 0.74013 to 0.75493, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.7837 - loss: 0.6485 - val_acc: 0.7549 - val_loss: 0.6057 - learning_rate: 0.0010
# Epoch 24/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.7922 - loss: 0.5673
# Epoch 24: val_acc did not improve from 0.75493
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.7922 - loss: 0.5673 - val_acc: 0.7418 - val_loss: 0.6214 - learning_rate: 0.0010
# Epoch 25/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.7686 - loss: 0.6791
# Epoch 25: val_acc improved from 0.75493 to 0.77138, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.7688 - loss: 0.6788 - val_acc: 0.7714 - val_loss: 0.6526 - learning_rate: 0.0010
# Epoch 26/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.7908 - loss: 0.6420
# Epoch 26: val_acc did not improve from 0.77138
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.7908 - loss: 0.6423 - val_acc: 0.7632 - val_loss: 0.6731 - learning_rate: 0.0010
# Epoch 27/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8042 - loss: 0.5562
# Epoch 27: val_acc improved from 0.77138 to 0.81414, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.8043 - loss: 0.5561 - val_acc: 0.8141 - val_loss: 0.5174 - learning_rate: 0.0010
# Epoch 28/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8014 - loss: 0.6659
# Epoch 28: val_acc did not improve from 0.81414
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.8017 - loss: 0.6644 - val_acc: 0.7714 - val_loss: 0.5117 - learning_rate: 0.0010
# Epoch 29/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.8210 - loss: 0.5465
# Epoch 29: val_acc did not improve from 0.81414
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.8207 - loss: 0.5476 - val_acc: 0.7911 - val_loss: 0.6552 - learning_rate: 0.0010
# Epoch 30/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8366 - loss: 0.4873
# Epoch 30: val_acc did not improve from 0.81414
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.8364 - loss: 0.4879 - val_acc: 0.7829 - val_loss: 0.6065 - learning_rate: 0.0010
# Epoch 31/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8431 - loss: 0.4828
# Epoch 31: val_acc did not improve from 0.81414
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8432 - loss: 0.4826 - val_acc: 0.8059 - val_loss: 0.5852 - learning_rate: 0.0010
# Epoch 32/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8359 - loss: 0.5314
# Epoch 32: val_acc did not improve from 0.81414
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8358 - loss: 0.5314 - val_acc: 0.7549 - val_loss: 0.7715 - learning_rate: 0.0010
# Epoch 33/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8490 - loss: 0.4202
# Epoch 33: val_acc improved from 0.81414 to 0.86020, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8490 - loss: 0.4203 - val_acc: 0.8602 - val_loss: 0.4069 - learning_rate: 0.0010
# Epoch 34/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8491 - loss: 0.4293
# Epoch 34: val_acc did not improve from 0.86020
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8491 - loss: 0.4294 - val_acc: 0.8339 - val_loss: 0.5104 - learning_rate: 0.0010
# Epoch 35/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8489 - loss: 0.4594
# Epoch 35: val_acc improved from 0.86020 to 0.87664, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8487 - loss: 0.4598 - val_acc: 0.8766 - val_loss: 0.3761 - learning_rate: 0.0010
# Epoch 36/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.8666 - loss: 0.3667
# Epoch 36: val_acc did not improve from 0.87664
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.8663 - loss: 0.3675 - val_acc: 0.8306 - val_loss: 0.5260 - learning_rate: 0.0010
# Epoch 37/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8292 - loss: 0.5696
# Epoch 37: val_acc did not improve from 0.87664
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8293 - loss: 0.5693 - val_acc: 0.7780 - val_loss: 0.8296 - learning_rate: 0.0010
# Epoch 38/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8596 - loss: 0.4249
# Epoch 38: val_acc did not improve from 0.87664
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8596 - loss: 0.4246 - val_acc: 0.8289 - val_loss: 0.4359 - learning_rate: 0.0010
# Epoch 39/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8564 - loss: 0.4110
# Epoch 39: val_acc did not improve from 0.87664
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8565 - loss: 0.4112 - val_acc: 0.8355 - val_loss: 0.3948 - learning_rate: 0.0010
# Epoch 40/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.8689 - loss: 0.4170
# Epoch 40: val_acc did not improve from 0.87664
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.8686 - loss: 0.4185 - val_acc: 0.8701 - val_loss: 0.3455 - learning_rate: 0.0010
# Epoch 41/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8744 - loss: 0.3928
# Epoch 41: val_acc did not improve from 0.87664
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.8744 - loss: 0.3928 - val_acc: 0.8701 - val_loss: 0.4271 - learning_rate: 0.0010
# Epoch 42/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8608 - loss: 0.4180
# Epoch 42: val_acc did not improve from 0.87664
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8609 - loss: 0.4173 - val_acc: 0.8240 - val_loss: 0.5845 - learning_rate: 0.0010
# Epoch 43/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.8765 - loss: 0.3714
# Epoch 43: val_acc improved from 0.87664 to 0.88980, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.8765 - loss: 0.3717 - val_acc: 0.8898 - val_loss: 0.2921 - learning_rate: 0.0010
# Epoch 44/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8522 - loss: 0.4943
# Epoch 44: val_acc improved from 0.88980 to 0.89474, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8522 - loss: 0.4941 - val_acc: 0.8947 - val_loss: 0.2866 - learning_rate: 0.0010
# Epoch 45/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8610 - loss: 0.3804
# Epoch 45: val_acc did not improve from 0.89474
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8611 - loss: 0.3803 - val_acc: 0.8092 - val_loss: 0.5841 - learning_rate: 0.0010
# Epoch 46/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8734 - loss: 0.3758
# Epoch 46: val_acc improved from 0.89474 to 0.90625, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8735 - loss: 0.3756 - val_acc: 0.9062 - val_loss: 0.2533 - learning_rate: 0.0010
# Epoch 47/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8843 - loss: 0.3288
# Epoch 47: val_acc did not improve from 0.90625
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.8843 - loss: 0.3290 - val_acc: 0.9046 - val_loss: 0.2494 - learning_rate: 0.0010
# Epoch 48/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8978 - loss: 0.2772
# Epoch 48: val_acc did not improve from 0.90625
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8977 - loss: 0.2773 - val_acc: 0.8997 - val_loss: 0.3012 - learning_rate: 0.0010
# Epoch 49/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8695 - loss: 0.3852
# Epoch 49: val_acc did not improve from 0.90625
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.8695 - loss: 0.3855 - val_acc: 0.8914 - val_loss: 0.2727 - learning_rate: 0.0010
# Epoch 50/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8847 - loss: 0.3550
# Epoch 50: val_acc did not improve from 0.90625
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8846 - loss: 0.3554 - val_acc: 0.7961 - val_loss: 0.6580 - learning_rate: 0.0010
# Epoch 51/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8654 - loss: 0.3886
# Epoch 51: val_acc did not improve from 0.90625
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8655 - loss: 0.3881 - val_acc: 0.8980 - val_loss: 0.2429 - learning_rate: 0.0010
# Epoch 52/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8987 - loss: 0.2784
# Epoch 52: val_acc did not improve from 0.90625
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8987 - loss: 0.2785 - val_acc: 0.8799 - val_loss: 0.3192 - learning_rate: 0.0010
# Epoch 53/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8878 - loss: 0.3506
# Epoch 53: val_acc did not improve from 0.90625
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8878 - loss: 0.3507 - val_acc: 0.8931 - val_loss: 0.3052 - learning_rate: 0.0010
# Epoch 54/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8943 - loss: 0.2808
# Epoch 54: val_acc did not improve from 0.90625
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8942 - loss: 0.2812 - val_acc: 0.8109 - val_loss: 0.8993 - learning_rate: 0.0010
# Epoch 55/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.8672 - loss: 0.5171
# Epoch 55: val_acc improved from 0.90625 to 0.91612, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8676 - loss: 0.5138 - val_acc: 0.9161 - val_loss: 0.2257 - learning_rate: 0.0010
# Epoch 56/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9017 - loss: 0.2699
# Epoch 56: val_acc did not improve from 0.91612
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9016 - loss: 0.2701 - val_acc: 0.8865 - val_loss: 0.3082 - learning_rate: 0.0010
# Epoch 57/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8788 - loss: 0.3762
# Epoch 57: val_acc did not improve from 0.91612
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.8789 - loss: 0.3760 - val_acc: 0.8257 - val_loss: 0.7501 - learning_rate: 0.0010
# Epoch 58/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8895 - loss: 0.3054
# Epoch 58: val_acc did not improve from 0.91612
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8896 - loss: 0.3051 - val_acc: 0.8586 - val_loss: 0.4535 - learning_rate: 0.0010
# Epoch 59/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.8801 - loss: 0.3606
# Epoch 59: val_acc did not improve from 0.91612
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.8804 - loss: 0.3593 - val_acc: 0.8602 - val_loss: 0.3259 - learning_rate: 0.0010
# Epoch 60/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9105 - loss: 0.2489
# Epoch 60: val_acc did not improve from 0.91612
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - acc: 0.9105 - loss: 0.2491 - val_acc: 0.8832 - val_loss: 0.3017 - learning_rate: 0.0010
# Epoch 61/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8780 - loss: 0.4270
# Epoch 61: val_acc improved from 0.91612 to 0.92105, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8780 - loss: 0.4267 - val_acc: 0.9211 - val_loss: 0.2045 - learning_rate: 0.0010
# Epoch 62/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8756 - loss: 0.4486
# Epoch 62: val_acc improved from 0.92105 to 0.92928, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8755 - loss: 0.4490 - val_acc: 0.9293 - val_loss: 0.1999 - learning_rate: 0.0010
# Epoch 63/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8992 - loss: 0.2677
# Epoch 63: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8993 - loss: 0.2677 - val_acc: 0.9178 - val_loss: 0.2018 - learning_rate: 0.0010
# Epoch 64/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - acc: 0.9143 - loss: 0.2349
# Epoch 64: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.9142 - loss: 0.2348 - val_acc: 0.9095 - val_loss: 0.2431 - learning_rate: 0.0010
# Epoch 65/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.8976 - loss: 0.2751
# Epoch 65: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8978 - loss: 0.2747 - val_acc: 0.8832 - val_loss: 0.3926 - learning_rate: 0.0010
# Epoch 66/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9170 - loss: 0.2273
# Epoch 66: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9169 - loss: 0.2275 - val_acc: 0.8816 - val_loss: 0.2908 - learning_rate: 0.0010
# Epoch 67/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9119 - loss: 0.2486
# Epoch 67: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.9120 - loss: 0.2484 - val_acc: 0.8306 - val_loss: 1.0888 - learning_rate: 0.0010
# Epoch 68/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.8833 - loss: 0.4307
# Epoch 68: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.8835 - loss: 0.4296 - val_acc: 0.9194 - val_loss: 0.2148 - learning_rate: 0.0010
# Epoch 69/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.9173 - loss: 0.2162
# Epoch 69: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.9173 - loss: 0.2165 - val_acc: 0.8997 - val_loss: 0.2329 - learning_rate: 0.0010
# Epoch 70/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9076 - loss: 0.2303
# Epoch 70: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.9076 - loss: 0.2303 - val_acc: 0.9276 - val_loss: 0.2002 - learning_rate: 0.0010
# Epoch 71/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9035 - loss: 0.2530
# Epoch 71: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.9037 - loss: 0.2525 - val_acc: 0.8980 - val_loss: 0.2374 - learning_rate: 0.0010
# Epoch 72/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - acc: 0.9217 - loss: 0.2160
# Epoch 72: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - acc: 0.9214 - loss: 0.2170 - val_acc: 0.8273 - val_loss: 0.7868 - learning_rate: 0.0010
# Epoch 73/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - acc: 0.9018 - loss: 0.2741
# Epoch 73: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - acc: 0.9021 - loss: 0.2727 - val_acc: 0.8635 - val_loss: 0.4257 - learning_rate: 0.0010
# Epoch 74/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.9199 - loss: 0.2151
# Epoch 74: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.9200 - loss: 0.2148 - val_acc: 0.8618 - val_loss: 0.4006 - learning_rate: 0.0010
# Epoch 75/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.9219 - loss: 0.1983
# Epoch 75: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - acc: 0.9219 - loss: 0.1985 - val_acc: 0.9178 - val_loss: 0.2039 - learning_rate: 0.0010
# Epoch 76/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - acc: 0.9461 - loss: 0.1474
# Epoch 76: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - acc: 0.9458 - loss: 0.1486 - val_acc: 0.8734 - val_loss: 0.4200 - learning_rate: 0.0010
# Epoch 77/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.9152 - loss: 0.2253
# Epoch 77: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - acc: 0.9151 - loss: 0.2255 - val_acc: 0.8405 - val_loss: 0.6597 - learning_rate: 0.0010
# Epoch 78/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9209 - loss: 0.2186
# Epoch 78: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9210 - loss: 0.2183 - val_acc: 0.9227 - val_loss: 0.1648 - learning_rate: 0.0010
# Epoch 79/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9341 - loss: 0.1732
# Epoch 79: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9341 - loss: 0.1735 - val_acc: 0.8882 - val_loss: 0.3013 - learning_rate: 0.0010
# Epoch 80/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9265 - loss: 0.1964
# Epoch 80: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.9264 - loss: 0.1967 - val_acc: 0.9276 - val_loss: 0.2056 - learning_rate: 0.0010
# Epoch 81/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9279 - loss: 0.1771
# Epoch 81: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9278 - loss: 0.1775 - val_acc: 0.8240 - val_loss: 0.7637 - learning_rate: 0.0010
# Epoch 82/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9149 - loss: 0.2509
# Epoch 82: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9152 - loss: 0.2496 - val_acc: 0.9030 - val_loss: 0.2186 - learning_rate: 0.0010
# Epoch 83/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9245 - loss: 0.2283
# Epoch 83: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9245 - loss: 0.2282 - val_acc: 0.8849 - val_loss: 0.3806 - learning_rate: 0.0010
# Epoch 84/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9435 - loss: 0.1503
# Epoch 84: val_acc did not improve from 0.92928
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9434 - loss: 0.1505 - val_acc: 0.8816 - val_loss: 0.4913 - learning_rate: 0.0010
# Epoch 85/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9308 - loss: 0.1769
# Epoch 85: val_acc improved from 0.92928 to 0.93750, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9308 - loss: 0.1772 - val_acc: 0.9375 - val_loss: 0.1633 - learning_rate: 0.0010
# Epoch 86/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9398 - loss: 0.1657
# Epoch 86: val_acc improved from 0.93750 to 0.96053, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.9397 - loss: 0.1662 - val_acc: 0.9605 - val_loss: 0.1094 - learning_rate: 0.0010
# Epoch 87/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9278 - loss: 0.2120
# Epoch 87: val_acc did not improve from 0.96053
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.9279 - loss: 0.2117 - val_acc: 0.9260 - val_loss: 0.2227 - learning_rate: 0.0010
# Epoch 88/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9381 - loss: 0.1837
# Epoch 88: val_acc did not improve from 0.96053
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9378 - loss: 0.1848 - val_acc: 0.9408 - val_loss: 0.1180 - learning_rate: 0.0010
# Epoch 89/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9522 - loss: 0.1329
# Epoch 89: val_acc did not improve from 0.96053
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9521 - loss: 0.1332 - val_acc: 0.9145 - val_loss: 0.3005 - learning_rate: 0.0010
# Epoch 90/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9396 - loss: 0.1841
# Epoch 90: val_acc did not improve from 0.96053
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9396 - loss: 0.1843 - val_acc: 0.9276 - val_loss: 0.1529 - learning_rate: 0.0010
# Epoch 91/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9512 - loss: 0.1252
# Epoch 91: val_acc did not improve from 0.96053
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9510 - loss: 0.1255 - val_acc: 0.9145 - val_loss: 0.2373 - learning_rate: 0.0010
# Epoch 92/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9556 - loss: 0.1067
# Epoch 92: val_acc did not improve from 0.96053
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.9555 - loss: 0.1069 - val_acc: 0.9589 - val_loss: 0.0964 - learning_rate: 0.0010
# Epoch 93/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.9476 - loss: 0.1373
# Epoch 93: val_acc did not improve from 0.96053
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.9475 - loss: 0.1378 - val_acc: 0.8898 - val_loss: 0.3245 - learning_rate: 0.0010
# Epoch 94/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9420 - loss: 0.1610
# Epoch 94: val_acc did not improve from 0.96053
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9421 - loss: 0.1608 - val_acc: 0.9260 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 95/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9566 - loss: 0.1088
# Epoch 95: val_acc improved from 0.96053 to 0.97204, saving model to models/model.keras
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.9565 - loss: 0.1093 - val_acc: 0.9720 - val_loss: 0.0764 - learning_rate: 0.0010
# Epoch 96/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.9656 - loss: 0.0881
# Epoch 96: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.9656 - loss: 0.0882 - val_acc: 0.9671 - val_loss: 0.0806 - learning_rate: 0.0010
# Epoch 97/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9632 - loss: 0.0879
# Epoch 97: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9631 - loss: 0.0880 - val_acc: 0.9704 - val_loss: 0.0747 - learning_rate: 0.0010
# Epoch 98/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9463 - loss: 0.1691
# Epoch 98: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9461 - loss: 0.1694 - val_acc: 0.9556 - val_loss: 0.1000 - learning_rate: 0.0010
# Epoch 99/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9503 - loss: 0.1167
# Epoch 99: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.9502 - loss: 0.1169 - val_acc: 0.9539 - val_loss: 0.1103 - learning_rate: 0.0010
# Epoch 100/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9564 - loss: 0.1064
# Epoch 100: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9564 - loss: 0.1065 - val_acc: 0.9457 - val_loss: 0.1230 - learning_rate: 0.0010
# Epoch 101/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.9322 - loss: 0.3213
# Epoch 101: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.9300 - loss: 0.3608 - val_acc: 0.6234 - val_loss: 5.6563 - learning_rate: 0.0010
# Epoch 102/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.4117 - loss: 200.1529
# Epoch 102: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.4089 - loss: 201.8764 - val_acc: 0.3372 - val_loss: 62.5222 - learning_rate: 0.0010
# Epoch 103/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.3311 - loss: 37.9852
# Epoch 103: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.3312 - loss: 37.9319 - val_acc: 0.4737 - val_loss: 11.6331 - learning_rate: 0.0010
# Epoch 104/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.4050 - loss: 25.6539
# Epoch 104: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.4047 - loss: 25.5827 - val_acc: 0.4934 - val_loss: 2.9834 - learning_rate: 0.0010
# Epoch 105/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.3522 - loss: 38.7352
# Epoch 105: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.3496 - loss: 39.3450 - val_acc: 0.0658 - val_loss: 834.2487 - learning_rate: 0.0010
# Epoch 106/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1431 - loss: 144.4571
# Epoch 106: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1431 - loss: 140.0624 - val_acc: 0.1513 - val_loss: 4.4358 - learning_rate: 0.0010
# Epoch 107/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1408 - loss: 4.2478
# Epoch 107: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1408 - loss: 4.2430 - val_acc: 0.1530 - val_loss: 3.6154 - learning_rate: 0.0010
# Epoch 108/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1422 - loss: 3.5440
# Epoch 108: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1423 - loss: 3.5396 - val_acc: 0.1530 - val_loss: 3.1685 - learning_rate: 0.0010
# Epoch 109/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1468 - loss: 3.2083
# Epoch 109: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1468 - loss: 3.2089 - val_acc: 0.1382 - val_loss: 5.7158 - learning_rate: 0.0010
# Epoch 110/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.2106 - loss: 31.7476
# Epoch 110: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.2114 - loss: 31.4163 - val_acc: 0.1957 - val_loss: 6.9364 - learning_rate: 0.0010
# Epoch 111/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1509 - loss: 18.6972
# Epoch 111: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1510 - loss: 18.6747 - val_acc: 0.1497 - val_loss: 2.7651 - learning_rate: 0.0010
# Epoch 112/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1448 - loss: 2.6687
# Epoch 112: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.1448 - loss: 2.6682 - val_acc: 0.1497 - val_loss: 2.6192 - learning_rate: 0.0010
# Epoch 113/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1415 - loss: 2.5567
# Epoch 113: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.1415 - loss: 2.5565 - val_acc: 0.1497 - val_loss: 2.4992 - learning_rate: 0.0010
# Epoch 114/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1452 - loss: 2.4214
# Epoch 114: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1451 - loss: 2.4213 - val_acc: 0.1497 - val_loss: 2.4004 - learning_rate: 0.0010
# Epoch 115/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1445 - loss: 2.3404
# Epoch 115: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1445 - loss: 2.3401 - val_acc: 0.1497 - val_loss: 2.3187 - learning_rate: 0.0010
# Epoch 116/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1420 - loss: 2.2654
# Epoch 116: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1420 - loss: 2.2653 - val_acc: 0.1497 - val_loss: 2.2515 - learning_rate: 0.0010
# Epoch 117/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1358 - loss: 2.2098
# Epoch 117: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.1360 - loss: 2.2096 - val_acc: 0.1497 - val_loss: 2.1956 - learning_rate: 0.0010
# Epoch 118/200
# 164/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1423 - loss: 2.1567
# Epoch 118: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1424 - loss: 2.1563 - val_acc: 0.1497 - val_loss: 2.1497 - learning_rate: 0.0010
# Epoch 119/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1430 - loss: 2.0967
# Epoch 119: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1430 - loss: 2.0970 - val_acc: 0.1497 - val_loss: 2.1115 - learning_rate: 0.0010
# Epoch 120/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1382 - loss: 2.0906
# Epoch 120: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1383 - loss: 2.0904 - val_acc: 0.1497 - val_loss: 2.0798 - learning_rate: 0.0010
# Epoch 121/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1393 - loss: 2.0666
# Epoch 121: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1394 - loss: 2.0662 - val_acc: 0.1497 - val_loss: 2.0534 - learning_rate: 0.0010
# Epoch 122/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1327 - loss: 2.0337
# Epoch 122: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1328 - loss: 2.0336 - val_acc: 0.1497 - val_loss: 2.0314 - learning_rate: 0.0010
# Epoch 123/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1414 - loss: 2.0119
# Epoch 123: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1414 - loss: 2.0119 - val_acc: 0.1497 - val_loss: 2.0135 - learning_rate: 0.0010
# Epoch 124/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1461 - loss: 1.9864
# Epoch 124: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1461 - loss: 1.9865 - val_acc: 0.1497 - val_loss: 1.9984 - learning_rate: 0.0010
# Epoch 125/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1384 - loss: 1.9820
# Epoch 125: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1385 - loss: 1.9820 - val_acc: 0.1497 - val_loss: 1.9859 - learning_rate: 0.0010
# Epoch 126/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1487 - loss: 1.9775
# Epoch 126: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1486 - loss: 1.9775 - val_acc: 0.1497 - val_loss: 1.9762 - learning_rate: 0.0010
# Epoch 127/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1431 - loss: 1.9687
# Epoch 127: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1431 - loss: 1.9686 - val_acc: 0.1497 - val_loss: 1.9683 - learning_rate: 0.0010
# Epoch 128/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1395 - loss: 1.9631
# Epoch 128: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1395 - loss: 1.9630 - val_acc: 0.1497 - val_loss: 1.9622 - learning_rate: 0.0010
# Epoch 129/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1411 - loss: 1.9551
# Epoch 129: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1412 - loss: 1.9551 - val_acc: 0.1497 - val_loss: 1.9578 - learning_rate: 0.0010
# Epoch 130/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1431 - loss: 1.9534
# Epoch 130: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1431 - loss: 1.9534 - val_acc: 0.1497 - val_loss: 1.9543 - learning_rate: 0.0010
# Epoch 131/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1468 - loss: 1.9499
# Epoch 131: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1467 - loss: 1.9499 - val_acc: 0.1497 - val_loss: 1.9520 - learning_rate: 0.0010
# Epoch 132/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1363 - loss: 1.9495
# Epoch 132: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1365 - loss: 1.9495 - val_acc: 0.1497 - val_loss: 1.9502 - learning_rate: 0.0010
# Epoch 133/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1412 - loss: 1.9479
# Epoch 133: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1412 - loss: 1.9479 - val_acc: 0.1497 - val_loss: 1.9491 - learning_rate: 0.0010
# Epoch 134/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1504 - loss: 1.9466
# Epoch 134: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.1501 - loss: 1.9467 - val_acc: 0.1497 - val_loss: 1.9482 - learning_rate: 0.0010
# Epoch 135/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1404 - loss: 1.9466
# Epoch 135: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1404 - loss: 1.9466 - val_acc: 0.1497 - val_loss: 1.9476 - learning_rate: 0.0010
# Epoch 136/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1467 - loss: 1.9460
# Epoch 136: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1465 - loss: 1.9460 - val_acc: 0.1497 - val_loss: 1.9473 - learning_rate: 0.0010
# Epoch 137/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1351 - loss: 1.9465
# Epoch 137: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1353 - loss: 1.9464 - val_acc: 0.1497 - val_loss: 1.9472 - learning_rate: 0.0010
# Epoch 138/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1379 - loss: 1.9464
# Epoch 138: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1379 - loss: 1.9464 - val_acc: 0.1497 - val_loss: 1.9471 - learning_rate: 0.0010
# Epoch 139/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1448 - loss: 1.9461
# Epoch 139: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1448 - loss: 1.9461 - val_acc: 0.1497 - val_loss: 1.9470 - learning_rate: 0.0010
# Epoch 140/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1429 - loss: 1.9457
# Epoch 140: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1428 - loss: 1.9457 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 0.0010
# Epoch 141/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1393 - loss: 1.9462
# Epoch 141: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1394 - loss: 1.9462 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 0.0010
# Epoch 142/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1474 - loss: 1.9456
# Epoch 142: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1473 - loss: 1.9456 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 0.0010
# Epoch 143/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1309 - loss: 1.9460
# Epoch 143: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.1312 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 0.0010
# Epoch 144/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1498 - loss: 1.9458
# Epoch 144: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1498 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 0.0010
# Epoch 145/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1394 - loss: 1.9460
# Epoch 145: val_acc did not improve from 0.97204
#
# Epoch 145: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1394 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 0.0010
# Epoch 146/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1499 - loss: 1.9460
# Epoch 146: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1498 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 147/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1507 - loss: 1.9459
# Epoch 147: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.1506 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 148/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1378 - loss: 1.9460
# Epoch 148: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1380 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 149/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1499 - loss: 1.9460
# Epoch 149: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1498 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 150/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1472 - loss: 1.9459
# Epoch 150: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1472 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 151/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1486 - loss: 1.9459
# Epoch 151: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.1486 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 152/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - acc: 0.1473 - loss: 1.9458
# Epoch 152: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - acc: 0.1473 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 153/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1463 - loss: 1.9459
# Epoch 153: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1463 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 154/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1441 - loss: 1.9458
# Epoch 154: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1442 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 155/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1460 - loss: 1.9459
# Epoch 155: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1460 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 156/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1537 - loss: 1.9459
# Epoch 156: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1536 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 157/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1400 - loss: 1.9460
# Epoch 157: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1401 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 158/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1512 - loss: 1.9457
# Epoch 158: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1511 - loss: 1.9457 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 159/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1450 - loss: 1.9458
# Epoch 159: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1449 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 160/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1422 - loss: 1.9460
# Epoch 160: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1422 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 161/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1458 - loss: 1.9460
# Epoch 161: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1458 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 162/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1449 - loss: 1.9461
# Epoch 162: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.1449 - loss: 1.9461 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 163/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1451 - loss: 1.9458
# Epoch 163: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1451 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 164/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1454 - loss: 1.9460
# Epoch 164: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1455 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 165/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1389 - loss: 1.9461
# Epoch 165: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1391 - loss: 1.9461 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 166/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1449 - loss: 1.9460
# Epoch 166: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1449 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 167/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1566 - loss: 1.9456
# Epoch 167: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1562 - loss: 1.9456 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 168/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1473 - loss: 1.9459
# Epoch 168: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1473 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 169/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1542 - loss: 1.9458
# Epoch 169: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1542 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 170/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1417 - loss: 1.9458
# Epoch 170: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1417 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 171/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1417 - loss: 1.9461
# Epoch 171: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.1417 - loss: 1.9461 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 172/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1471 - loss: 1.9455
# Epoch 172: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1471 - loss: 1.9455 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 173/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1493 - loss: 1.9459
# Epoch 173: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1493 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 174/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1494 - loss: 1.9458
# Epoch 174: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1493 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 175/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1395 - loss: 1.9460
# Epoch 175: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1396 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 176/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1488 - loss: 1.9457
# Epoch 176: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1487 - loss: 1.9457 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 177/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1544 - loss: 1.9454
# Epoch 177: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1543 - loss: 1.9454 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 178/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1476 - loss: 1.9459
# Epoch 178: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1476 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 179/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1456 - loss: 1.9460
# Epoch 179: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1456 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9467 - learning_rate: 5.0000e-04
# Epoch 180/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1486 - loss: 1.9457
# Epoch 180: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1486 - loss: 1.9457 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 181/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1432 - loss: 1.9459
# Epoch 181: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1432 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 182/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - acc: 0.1399 - loss: 1.9458
# Epoch 182: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - acc: 0.1401 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 183/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1358 - loss: 1.9461
# Epoch 183: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1362 - loss: 1.9461 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 184/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1533 - loss: 1.9456
# Epoch 184: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1532 - loss: 1.9456 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 185/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1424 - loss: 1.9460
# Epoch 185: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.1425 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 186/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1511 - loss: 1.9457
# Epoch 186: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1509 - loss: 1.9457 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 187/200
# 167/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1492 - loss: 1.9458
# Epoch 187: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - acc: 0.1491 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 188/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1535 - loss: 1.9455
# Epoch 188: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1533 - loss: 1.9455 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 189/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1432 - loss: 1.9461
# Epoch 189: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1432 - loss: 1.9461 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 190/200
# 169/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1418 - loss: 1.9458
# Epoch 190: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1419 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 191/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - acc: 0.1499 - loss: 1.9458
# Epoch 191: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1497 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 192/200
# 165/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1453 - loss: 1.9461
# Epoch 192: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.1453 - loss: 1.9461 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 193/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1382 - loss: 1.9461
# Epoch 193: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1384 - loss: 1.9461 - val_acc: 0.1266 - val_loss: 1.9469 - learning_rate: 5.0000e-04
# Epoch 194/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1408 - loss: 1.9460
# Epoch 194: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - acc: 0.1408 - loss: 1.9460 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 195/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - acc: 0.1416 - loss: 1.9459
# Epoch 195: val_acc did not improve from 0.97204
# Epoch 195: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1418 - loss: 1.9459 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 5.0000e-04
# Epoch 196/200
# 168/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1469 - loss: 1.9456
# Epoch 196: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.1468 - loss: 1.9456 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 2.5000e-04
# Epoch 197/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1451 - loss: 1.9458
# Epoch 197: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.1451 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 2.5000e-04
# Epoch 198/200
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1465 - loss: 1.9458
# Epoch 198: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.1465 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 2.5000e-04
# Epoch 199/200
# 170/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1413 - loss: 1.9458
# Epoch 199: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - acc: 0.1414 - loss: 1.9458 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 2.5000e-04
# Epoch 200/200
# 166/171 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - acc: 0.1428 - loss: 1.9461
# Epoch 200: val_acc did not improve from 0.97204
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - acc: 0.1429 - loss: 1.9461 - val_acc: 0.1266 - val_loss: 1.9468 - learning_rate: 2.5000e-04

# %% [markdown]
# 결론
# 이렇게 해서 우리는 LSTM 기반의 딥러닝 모델을 정의하고, 이를 컴파일하고, 학습시키는 전체 과정을 살펴보았습니다. 각 단계마다 중요한 설정들이 있으며, 이러한 설정들이 모델의 성능에 큰 영향을 미칩니다. 오늘 설명드린 내용이 여러분의 딥러닝 모델 구축에 도움이 되길 바랍니다. 감사합니다.

# %% [markdown]
# # 모델 성능 평가

# %% [markdown]
# ## 손실/정확도 시각화
#
#
# 그래프 생성: matplotlib 라이브러리를 사용하여 손실과 정확도를 시각화합니다.
#
# 손실 그래프 설정: 학습 손실과 검증 손실을 각각 노란색과 빨간색으로 표시합니다.
#
# 정확도 그래프 설정: 학습 정확도와 검증 정확도를 각각 파란색과 녹색으로 표시합니다.
#
# 결과 시각화: 에포크(epoch)별로 모델의 성능 변화를 쉽게 파악할 수 있습니다.

# %%
import matplotlib.pyplot as plt

# 그래프 생성
fig, loss_ax = plt.subplots(figsize=(16, 10))
acc_ax = loss_ax.twinx()

# 손실 그래프 설정
loss_ax.plot(history.history['loss'], 'y', label='train loss')
loss_ax.plot(history.history['val_loss'], 'r', label='val loss')
loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
loss_ax.legend(loc='upper left')

# 정확도 그래프 설정
acc_ax.plot(history.history['acc'], 'b', label='train acc')
acc_ax.plot(history.history['val_acc'], 'g', label='val acc')
acc_ax.set_ylabel('accuracy')
acc_ax.legend(loc='upper left')

# 그래프 출력
plt.show()

# %% [markdown]
# ## 모델 로드 및 검증 데이터 예측
#
# 모델 로드: tensorflow.keras.models의 load_model 함수를 사용하여 저장된 모델을 불러옵니다.
#
# 모델 예측: 로드된 모델을 사용하여 검증 데이터에 대한 예측을 수행합니다.
#
# 검증 데이터: 사전에 분리된 데이터를 사용하여 모델의 일반화 성능을 평가합니다.
#
# ## 다중 라벨 혼동 행렬 계산
#
# 혼동 행렬: sklearn.metrics의 multilabel_confusion_matrix를 사용하여 다중 라벨 분류 문제의 성능을 평가합니다.
#
# 혼동 행렬 계산: 실제 라벨과 예측 라벨을 비교하여 각 클래스에 대한 혼동 행렬을 생성합니다.
#
# 결과 해석: 혼동 행렬을 통해 모델이 어떤 클래스에서 잘못된 예측을 했는지 구체적으로 파악할 수 있습니다.

# %%
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.models import load_model

# 저장된 모델 로드
model = load_model('models/model.keras')

# 검증 데이터를 사용하여 모델의 예측 수행
y_pred = model.predict(x_val)

# 다중 라벨 혼동 행렬 계산
confusion_matrices = multilabel_confusion_matrix(np.argmax(y_val, axis=1), np.argmax(y_pred, axis=1))

# 다중 라벨 혼동 행렬 출력
confusion_matrices
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[[518,   0],
#         [  0,  90]],
#
#        [[531,   0],
#         [  0,  77]],
#
#        [[526,   0],
#         [  0,  82]],
#
#        [[530,   1],
#         [  0,  77]],
#
#        [[517,   0],
#         [  1,  90]],
#
#        [[509,   5],
#         [ 11,  83]],
#
#        [[500,  11],
#         [  5,  92]]], dtype=int64)

# %% [markdown]
# ## 예외 처리 및 파일 존재 여부 확인   : ppt(X)
#
# 예외 처리: 모델 파일이 존재하지 않을 경우를 대비하여 예외 처리를 수행합니다.
#
# 파일 확인: os.path.exists를 사용하여 모델 파일의 존재 여부를 확인합니다.
#
# 오류 처리: 파일이 존재하지 않을 경우 FileNotFoundError를 발생시켜 사용자에게 알립니다.
#
# 전체 흐름: 모델 로드, 예측, 혼동 행렬 계산, 및 예외 처리를 포함한 전체 흐름을 관리합니다.

# %%
from sklearn.metrics import multilabel_confusion_matrix
from tensorflow.keras.models import load_model
import os

# 모델 파일 경로 정의
model_file = 'models/model.keras'

try:
    # 파일 존재 여부 확인
    if os.path.exists(model_file):
        # 모델 로드
        model = load_model(model_file)

        # 검증 데이터에 대한 예측 수행
        y_pred = model.predict(x_val)

        # 다중 라벨 혼동 행렬 계산
        confusion_matrices = multilabel_confusion_matrix(np.argmax(y_val, axis=1), np.argmax(y_pred, axis=1))

        # 혼동 행렬 출력
        print(confusion_matrices)
    else:
        raise FileNotFoundError(f"모델 파일 '{model_file}'을 찾을 수 없습니다.")
except Exception as e:
    print("오류가 발생했습니다:", e)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [[[518   0]
#   [  0  90]]
#
#  [[531   0]
#   [  0  77]]
#
#  [[526   0]
#   [  0  82]]
#
#  [[530   1]
#   [  0  77]]
#
#  [[517   0]
#   [  1  90]]
#
#  [[509   5]
#   [ 11  83]]
#
#  [[500  11]
#   [  5  92]]]
